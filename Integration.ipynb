# %% [markdown]
# <a href="https://colab.research.google.com/github/applejxd/applejxd.github.io/blob/master/Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 数値積分法の精度を円周率の計算
# \begin{equation}
#     I\equiv\int_a^b dx f(x)
#     =\int_{0}^1dx\frac{4}{1+x^2}=\pi
# \end{equation}
# で比較する。

# %% [markdown]
# 台形公式は
# \begin{equation}
# \begin{split}
#     &I\simeq\frac{\Delta x}{2}\left(f(x_0)+2\sum_{k=1}^{n-1}f(x_k)+f(x_n)\right)
#     =\Delta x\left(2+\sum_{k=1}^{n-1}\frac{4}{1+x_k^2}+1\right),\\
#     &\Delta x\equiv\frac{1}{n},\quad
#     x_k\equiv k\Delta x
# \end{split}
# \end{equation}
# となる。

# %%
import numpy as np

#: 分割数
num: float = 100.

#: 被積分関数
def integrand(x: float) -> float:
    return 4 / (1 + x**2)

# %%
from typing import Callable

def trapezoid(integrand: Callable[[float], float], num: float) -> float:
    # 分割幅
    dx: float = 1./num
    # 台形公式
    sum: float = 3. * dx
    x_list: np.ndarray = np.arange(dx, 1., dx)
    for x_k in x_list:
        sum += dx * integrand(x_k)
    return sum

print(trapezoid(integrand, num))
# Out:
# 3.141575986923127

# %% [markdown]
# シンプソン公式は
# \begin{equation}
# \begin{split}
#     &I\simeq\frac{\Delta x}{3}\left(f(x_0)+4\sum_{k=1,3,\cdots}^{2n-1}f(x_k)+2\sum_{k=2,4,\cdots}^{2n-2}f(x_k)+f(x_{2n})\right)\\
#     &=\frac{\Delta x}{3}\left(4+\sum_{k=1,3,\cdots}^{2n-1}\frac{16}{1+x_k^2}+\sum_{k=2,4,\cdots}^{2n-2}\frac{8}{1+x_k^2}+2\right),\\
#     &\Delta x\equiv\frac{1-(-1)}{2n},\quad
#     x_k\equiv-1+k\Delta x
# \end{split}
# \end{equation}
# となる。

# %%
def Simpson(integrand: Callable[[float], float], num: float) -> float:
    iter_num: float = num / 2.
    dx = 1./(2 * iter_num)
    sum = 2 * dx
    x_odd_list: np.ndarray = np.arange(dx, 1., 2*dx)
    x_even_list: np.ndarray = np.arange(2*dx, 1.-dx, 2*dx)

    for x_k in x_odd_list:
        sum += dx * 16./3. / (1+x_k**2)
    for x_k in x_even_list:
        sum += dx * 8./3. / (1+x_k**2)
    return sum

print(Simpson(integrand, num))
# Out:
# 3.141592653589754

# %% [markdown]
# ロンバーグ法

# %% [markdown]
# ガウス・ルジャンドル積分
